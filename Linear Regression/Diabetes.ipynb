# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
len(data)
# Out:
# 768

# %%
preg=[]
for i in range(len(data)):
    if data['Outcome'][i]==1:
        preg.append(data['Pregnancies'][i])

# %%
plt.hist(preg)
plt.xlabel('Number of Time Pregnant')
#Number of times inversely related to diabetes occurance
# Out:
# Text(0.5,0,'Number of Time Pregnant')

# %%
glue=[]
for i in range(len(data)):
    if data['Outcome'][i]==1:
        glue.append(data['Glucose'][i])

# %%
plt.hist(glue)
plt.xlabel('Glucose')
#between 125-150-hishest prob of diabeties
# Out:
# Text(0.5,0,'Glucose')

# %%
# It change it output conditin will not be there
press=[]
for i in range(len(data)):
    press.append(data['BloodPressure'][i])

# %%
plt.hist(press)
plt.xlabel('BloodPressure')
# Out:
# Text(0.5,0,'BloodPressure')

# %%
skin=[]
for i in range(len(data)):
    if data['Outcome'][i]==1:
        skin.append(data['SkinThickness'][i])

# %%
plt.hist(skin)
plt.xlabel('Skin Thickness')
# Out:
# Text(0.5,0,'Skin Thickness')

# %%
skin=[]
for i in range(len(data)):
    skin.append(data['SkinThickness'][i])

# %%
plt.hist(skin)
plt.xlabel('Skin Thickness')
# Out:
# Text(0.5,0,'Skin Thickness')

# %%
insulin=[]
for i in range(len(data)):
    insulin.append(data['Insulin'][i])

# %%
plt.hist(insulin)
plt.xlabel('Insulin')
# Out:
# Text(0.5,0,'Insulin')

# %%
bmi=[]
for i in range(len(data)):
    bmi.append(data['BMI'][i])

# %%
plt.hist(bmi)
plt.xlabel('BMI')
# Out:
# Text(0.5,0,'BMI')

# %%
fun=[]
for i in range(len(data)):
    fun.append(data['DiabetesPedigreeFunction'][i])

# %%
plt.hist(fun)
plt.xlabel('Diabetes Pedigree Function')
# Out:
# Text(0.5,0,'Diabetes Pedigree Function')

# %%
age=[]
for i in range(len(data)):
    if data['Outcome'][i]==1:
        age.append(data['Age'][i])

# %%
plt.hist(age)
plt.xlabel('Age')
# Out:
# Text(0.5,0,'Age')
